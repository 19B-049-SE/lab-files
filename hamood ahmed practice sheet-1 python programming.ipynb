# %%
# program no.1
import math
no1=math.sqrt(4)
no2=math.radians(45)
no3=math.sin(90)
no4=math.cos(90)
no5=math.tan(45)
no6=math.e
no7=math.pi
no8=math.log10(20)
no9=math.pow(2,6)
no10=math.asinh(0.86)
print(no1,no2,no3,no4,no5,no6,no7,no8,no9,no10)
# Out:
# 2.0 0.7853981633974483 0.8939966636005579 -0.4480736161291701 1.6197751905438615 2.718281828459045 3.141592653589793 1.3010299956639813 64.0 0.7788380461639725

# %%
#program no.3
name=len('Hamood Ahmed')
print(name)
# Out:
# 12

# %%
#program no.4
name='Hamood Ahmed'
print(type(name))
# Out:
# <class 'str'>

# %%
#program no.5
import math
velocity=int(input("enter the velocity of football in m/sec:"))
angle=int(input("enter the angle(theta) in degrees:"))
height=int(input("enter the height in meters:"))
gravity=9.8 #Earth gravity
y=('absolute height')

#converting angles to radians
angleRad =math.radians(angle)

#calculations
height=(velocity**2 * y/2 * gravity)
print("height")
# Out:
# enter the velocity of football in m/sec:15
# enter the angle(theta) in degrees:30
# enter the height in meters:1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-19eb5a2adf82> in <module>
#      11
#      12 #calculations
# ---> 13 height=(velocity**2 * y/2 * gravity)
#      14 print("height")
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
#program no.7
#part-a) To find the current I1,I2,I3 when 10V voltage is coonected in parallel across the resistances R1,R2 and R3
import math
V=float(input("enter the value of voltage in volts:"))
R1=float(input("enter the value of resistance R1 in ohms:"))
R2=float(input("enter the value of resistance R2 in ohms:"))
R3=float(input("enter the value of resistance R3 in ohms:"))
I=("current supplied")
I1=((V)/R1)
I2=((V)/R2)
I3=((V)/R3)
print(I1,"amperes")
print(I2,"amperes")
print(I3,"amperes")

#part-b)To find the voltage V1,V2,V3 when 10v voltage is connected in parallel across the resistances R1,R2 and R3
R=float(input("enter the value of total resistance in ohms:"))
I1=float(input("enter the value of current in amperes:"))
I2=float(input("enter the value of current in amperes:"))
I3=float(input("enter the value of current in amperes:"))
R=("total resistance")
V1=(I1*(R))
V2=(I2*(R))
V3=(I3*(R))
print(V1,"volts")
print(V2,"volts")
print(V3,"volts")
# Out:
# enter the value of voltage in volts:10
# enter the value of resistance R1 in ohms:10
# enter the value of resistance R2 in ohms:20
# enter the value of resistance R3 in ohms:30
# 1.0 amperes
# 0.5 amperes
# 0.3333333333333333 amperes
# enter the value of total resistance in ohms:60
# enter the value of current in amperes:1
# enter the value of current in amperes:0.5
# enter the value of current in amperes:0.33333
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-89d52619e640> in <module>
#      20 I3=float(input("enter the value of current in amperes:"))
#      21 R=("total resistance")
# ---> 22 V1=(I1*(R))
#      23 V2=(I2*(R))
#      24 V3=(I3*(R))
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
#program no.2:Use help() command to show what is math library,int and class.
help(math)
help(int)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module is always available.  It provides access to the
#     mathematical functions defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(x, /)
#         Return the ceiling of x as an Integral.
#
#         This is the smallest integer >= x.
#
#     copysign(x, y, /)
# ...

# %%
#program no.4:We use type() function to show the type of the variable. Your task is to use it on different type of variables in which you save your name, date of birth, cell number, email, favourite dish, favourite color, favourite movie, favourite flower, etc.
name="Hamood Ahmed"
cell=(0,3,4,5,6,7,8,9,4,0,0)
email="poppyman09@gmail.com"
favdish="pizza"
favmov="the expandables 2"
address=('G','u','l','b','e','r','g')
weather=2>4
age=19
print(type(name),type(cell),type(email),type(favdish),type(favmov),type(address),type(weather),type(age))
# Out:
# <class 'str'> <class 'tuple'> <class 'str'> <class 'str'> <class 'str'> <class 'tuple'> <class 'bool'> <class 'int'>

# %%
#Program no.10
# part-1
height_pole=5.6 #in meter
shadow_pole=3.2 #in meter
shadow_pole2=10.5 #in meter
height_pole2=(height_pole*shadow_pole2/shadow_pole)
print(str(height_pole2)+'meter')

 # part-2
height_pole=5.6 #in meter
shadow_pole=3.2 #in meter
shadow_pole2=5 #in meter
height_pole2=(height_pole*shadow_pole2/shadow_pole)
print(str(height_pole2)+'meter')
# Out:
# 18.374999999999996meter
# 8.75meter

# %%
#program no.5
#part-a
import math
from math import sin
velocity=15
g=9.8
angle=30
angleRad=math.radians(angle)
Height=(velocity**2*sin(angleRad)**2/2*g)
print(str(Height)+'meter')

#part-b
velocity=15
g=9.8
angle=30
angleRad=math.radians(angle)
t=(2*velocity*sin(angleRad)/9.8)
T=2*t
print(str(T)+"sec")

#part-c
velocity=15
g=9.8
angle=30
angleRad=math.radians(angle)
R=(velocity**2*sin(angleRad*2)/g)
print(str(R)+'meter')

#part-d
from math import cos
velocity=15
angle=30
angleRad=math.radians(angle)
velocity_Y=0
velocity_X=(velocity*cos(angleRad))
print(velocity_Y)
print(str(velocity_X)+'m/s')

#part-e
velocity=15
angle=30
angleRad=math.radians(angle)
velocity_Y=0
velocity_X=(velocity*cos(angleRad))
v=math.sqrt((velocity_X)**2+(velocity_Y)**2)
print(str(v)+'m/s')
# Out:
# 275.62499999999994meter
# 3.0612244897959178sec
# 19.883236311377413meter
# 0
# 12.99038105676658m/s
# 12.99038105676658m/s
